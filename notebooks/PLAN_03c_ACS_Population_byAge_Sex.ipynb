# %% [markdown]
# <a href="https://colab.research.google.com/github/npr99/PlanningMethods/blob/master/PLAN604_ACS_Population_byAge_Sex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Application of Population Compostion by Age and Sex from ACS Data
#
# ---
# This Google Colab Notebook provides a complete workflow (sequence of steps from start to finish) that will allow you to explore population composition data by age and sex found in ACS Data.
#
# This notebook obtains and cleans population percentages found in the ACS.
#
# The notebook also explores outliers for a single age and sex composition.
#
# ### Assignment Steps:
# 1. Run all blocks of the notebook.
# 2. On step for change the code by selecting a sex and age cohort to explore outliers
# 3. Choose a state to find a specific county
# 4. Update the last block of code with the county you want to explore in more detail
# 5. In the class discussion board on Canvas create a discussion post about the county you found to be an outlier

# %% [markdown]
# Helpful Links that inspired this notebook:
#
# https://www.youtube.com/watch?v=jMBaY-rO4G0
#
# https://walker-data.com/tidycensus/articles/other-datasets.html#migration-flows-1

# %% [markdown]
# #  Your Choice
# In the code block below select a sex and age cohort to explore.
#
# Sex Options, choose one by uncommenting the line of code.
#
# Age Cohort Options, choose one by uncommenting the line of code.
#
# Leave year as 2019.
#
# Select a state based on FIPS code [see link](https://www.census.gov/library/reference/code-lists/ansi/ansi-codes-for-states.html).
#
# To uncomment - remove the # from the beginning of the line of code, and add a # to the beginning of the line of code that is currently uncommented.

# %%
# Select Sex (uncomment one line)
sex = "Female"
#sex = "Male"

# Select age cohort (uncomment one line)
#agecohort = "Under 5"
#agecohort = "5 to 9"
#agecohort = "10 to 14"
#agecohort = "15 to 19"
agecohort = "20 to 24"
#agecohort = "25 to 29"
#agecohort = "30 to 34"
#agecohort = "35 to 39"
#agecohort = "40 to 44"
#agecohort = "45 to 49"
#agecohort = "50 to 54"
#agecohort = "55 to 59"
#agecohort = "60 to 64"
#agecohort = "65 to 69"
#agecohort = "70 to 74"
#agecohort = "75 to 79"
#agecohort = "80 to 84"
#agecohort = "85"

# Select state by FIPS Code
state = '48'

# Select year (leave as 2019 for now)
year = '2019'

# %%
# Downloading and running python script from github
# https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html
# Make sure the url is the raw version of the file on GitHub

user = "npr99"
repo = "PlanningMethods"
pyfile = "_planning_methods.py"
url = f"https://raw.githubusercontent.com/{user}/{repo}/master/{pyfile}"
# !wget --no-cache --quiet --backups=1 {url}
print("Reading in python file from",url)
exec(open(pyfile).read())
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# Reading in python file from https://raw.githubusercontent.com/npr99/PlanningMethods/master/_planning_methods.py

# %% [markdown]
# ## Steps 1 and 2: Obtain Data and Clean Data
# The previous step read in a python file with the Obtain Data and Clean Data functions presented in the notebook on [Sample Size and Confidence Intervals](https://github.com/npr99/PlanningMethods/blob/master/PLAN604_Population_vs_Sample_USCounties.ipynb) and the notebook on [Comparison of two proportions](https://github.com/npr99/PlanningMethods/blob/master/PLAN604_Comparison_of_two_proportions_tractlevel.ipynb). The block of code with the python functions needs to be run first and then the function can be called in future blocks of code.

# %% [markdown]
# ## Run Obtain Census API for ACS data with Age and Sex Charactersitics
# The next block of code calls the function and gets varaibles related to public transportation use. The code is called in a loop.
#
# For more variables see:
# 3                      0.9                             6.8
# 4                      1.2                             5.1
#
#    10 to 14 years 2019 (MOE)  ...  70 to 74 years 2019 (Estimate)  \
# 0                        0.2  ...                             3.2
# 1                        0.6  ...                             4.6
# 2                        0.7  ...                             3.8
# 3                        1.1  ...                             4.1
# 4                        1.2  ...                             5.9
#
#    70 to 74 years 2019 (MOE)  75 to 79 years 2019 (Estimate)  \
# 0                        0.1                             2.1
# 1                        0.7                             3.5
# 2                        0.6                             2.9
# 3                        0.8                             3.1
# 4                        1.0                             3.8
#
#    75 to 79 years 2019 (MOE)  80 to 84 years 2019 (Estimate)  \
# 0                        0.1                             1.3
# 1                        0.6                             1.6
# 2                        0.5                             1.4
# 3                        0.7                             2.2
# 4                        0.9                             2.9
#
#    80 to 84 years 2019 (MOE)  85 years and over 2019 (Estimate)  \
# 0                        0.1                                1.2
# 1                        0.4                                1.7
# 2                        0.4                                2.4
# 3                        0.5                                1.8
# 4                        0.9                                1.5
#
#    85 years and over 2019 (MOE)  state  county
# 0                           0.1     17     097
# 1                           0.5     17     051
# 2                           0.6     17     107
# 3                           0.5     17     165
# 4                           0.7     17     127
#
# [5 rows x 42 columns]

# %%
acs_df['2019 Percent Female'].head()
# Out:
#         Geography      Geographic Area Name  Total population 2019 (Estimate)  \
# 0  0500000US17097     Lake County, Illinois                            351007
# 1  0500000US17051  Fayette County, Illinois                             10096
# 2  0500000US17107    Logan County, Illinois                             14705
# 3  0500000US17165   Saline County, Illinois                             12187
# 4  0500000US17127   Massac County, Illinois                              7505
#
#    Total population 2019 (MOE)  Under 5 years 2019 (Estimate)  \
# 0                         84.0                            5.7
# 1                        113.0                            5.6
# 2                        218.0                            4.9
# 3                        118.0                            5.7
# 4                         54.0                            5.4
#
#    Under 5 years 2019 (MOE)  5 to 9 years 2019 (Estimate)  \
# 0                       0.1                           6.4
# 1                       0.1                           4.9
# 2                       0.2                           4.9
# 3                       0.2                           4.7
# 4                       0.5                           9.5
#
#    5 to 9 years 2019 (MOE)  10 to 14 years 2019 (Estimate)  \
# 0                      0.2                             7.2
# 1                      1.2                             7.0
# 2                      0.6                             5.3
# 3                      1.0                             6.4
# 4                      1.4                             4.3
#
#    10 to 14 years 2019 (MOE)  ...  70 to 74 years 2019 (Estimate)  \
# 0                        0.2  ...                             3.5
# 1                        0.8  ...                             5.7
# 2                        0.5  ...                             4.4
# 3                        0.8  ...                             5.7
# 4                        1.4  ...                             5.4
#
#    70 to 74 years 2019 (MOE)  75 to 79 years 2019 (Estimate)  \
# 0                        0.2                             2.4
# 1                        0.8                             4.7
# 2                        0.5                             3.1
# 3                        0.9                             3.7
# 4                        1.0                             3.6
#
#    75 to 79 years 2019 (MOE)  80 to 84 years 2019 (Estimate)  \
# 0                        0.1                             1.7
# 1                        0.8                             3.1
# 2                        0.6                             2.0
# 3                        0.8                             2.8
# 4                        1.0                             4.1
#
#    80 to 84 years 2019 (MOE)  85 years and over 2019 (Estimate)  \
# 0                        0.1                                2.3
# 1                        0.6                                2.9
# 2                        0.4                                5.1
# 3                        0.7                                4.1
# 4                        1.3                                3.6
#
#    85 years and over 2019 (MOE)  state  county
# 0                           0.1     17     097
# 1                           0.7     17     051
# 2                           0.6     17     107
# 3                           0.8     17     165
# 4                           1.0     17     127
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Step 3: Explore Data

# %% [markdown]
# #### 3.1 Use descriptive statistics to check cleaning
# A descriptive statistics table is a great way to check to make sure the variables have been created correctly.

# %%
planning_methods.descriptive_stats_table(acs_df['2019 Percent Male'], 
      who = "Percent male population by age",
      what = "descriptive statistics",
      when = "in 2015-2019",
      where = "for all US counties")
# Out:
# <style type="text/css">
# #T_b04cd caption {
#   text-align: center;
#   caption-side: top;
#   font-size: 150%;
#   color: black;
# }
# #T_b04cd_row0_col0, #T_b04cd_row0_col1, #T_b04cd_row0_col2, #T_b04cd_row0_col3, #T_b04cd_row0_col4, #T_b04cd_row0_col5, #T_b04cd_row0_col6, #T_b04cd_row0_col7, #T_b04cd_row1_col0, #T_b04cd_row1_col1, #T_b04cd_row1_col2, #T_b04cd_row1_col3, #T_b04cd_row1_col4, #T_b04cd_row1_col5, #T_b04cd_row1_col6, #T_b04cd_row1_col7, #T_b04cd_row2_col0, #T_b04cd_row2_col1, #T_b04cd_row2_col2, #T_b04cd_row2_col3, #T_b04cd_row2_col4, #T_b04cd_row2_col5, #T_b04cd_row2_col6, #T_b04cd_row2_col7, #T_b04cd_row3_col0, #T_b04cd_row3_col1, #T_b04cd_row3_col2, #T_b04cd_row3_col3, #T_b04cd_row3_col4, #T_b04cd_row3_col5, #T_b04cd_row3_col6, #T_b04cd_row3_col7, #T_b04cd_row4_col0, #T_b04cd_row4_col1, #T_b04cd_row4_col2, #T_b04cd_row4_col3, #T_b04cd_row4_col4, #T_b04cd_row4_col5, #T_b04cd_row4_col6, #T_b04cd_row4_col7, #T_b04cd_row5_col0, #T_b04cd_row5_col1, #T_b04cd_row5_col2, #T_b04cd_row5_col3, #T_b04cd_row5_col4, #T_b04cd_row5_col5, #T_b04cd_row5_col6, #T_b04cd_row5_col7, #T_b04cd_row6_col0, #T_b04cd_row6_col1, #T_b04cd_row6_col2, #T_b04cd_row6_col3, #T_b04cd_row6_col4, #T_b04cd_row6_col5, #T_b04cd_row6_col6, #T_b04cd_row6_col7, #T_b04cd_row7_col0, #T_b04cd_row7_col1, #T_b04cd_row7_col2, #T_b04cd_row7_col3, #T_b04cd_row7_col4, #T_b04cd_row7_col5, #T_b04cd_row7_col6, #T_b04cd_row7_col7, #T_b04cd_row8_col0, #T_b04cd_row8_col1, #T_b04cd_row8_col2, #T_b04cd_row8_col3, #T_b04cd_row8_col4, #T_b04cd_row8_col5, #T_b04cd_row8_col6, #T_b04cd_row8_col7, #T_b04cd_row9_col0, #T_b04cd_row9_col1, #T_b04cd_row9_col2, #T_b04cd_row9_col3, #T_b04cd_row9_col4, #T_b04cd_row9_col5, #T_b04cd_row9_col6, #T_b04cd_row9_col7, #T_b04cd_row10_col0, #T_b04cd_row10_col1, #T_b04cd_row10_col2, #T_b04cd_row10_col3, #T_b04cd_row10_col4, #T
years 2019 (Estimate)</th>
#       <td id="T_b04cd_row2_col0" class="data row2 col0" >3,220.00</td>
#       <td id="T_b04cd_row2_col1" class="data row2 col1" >6.59</td>
#       <td id="T_b04cd_row2_col2" class="data row2 col2" >1.47</td>
#       <td id="T_b04cd_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_b04cd_row2_col4" class="data row2 col4" >5.80</td>
#       <td id="T_b04cd_row2_col5" class="data row2 col5" >6.60</td>
#       <td id="T_b04cd_row2_col6" class="data row2 col6" >7.40</td>
#       <td id="T_b04cd_row2_col7" class="data row2 col7" >21.40</td>
#     </tr>
#     <tr>
#       <th id="T_b04cd_level0_row3" class="row_heading level0 row3" >15 to 19 years 2019 (Estimate)</th>
#       <td id="T_b04cd_row3_col0" class="data row3 col0" >3,220.00</td>
#       <td id="T_b04cd_row3_col1" class="data row3 col1" >6.71</td>
#       <td id="T_b04cd_row3_col2" class="data row3 col2" >1.63</td>
#       <td id="T_b04cd_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_b04cd_row3_col4" class="data row3 col4" >5.90</td>
#       <td id="T_b04cd_row3_col5" class="data row3 col5" >6.70</td>
#       <td id="T_b04cd_row3_col6" class="data row3 col6" >7.30</td>
#       <td id="T_b04cd_row3_col7" class="data row3 col7" >28.30</td>
#     </tr>
#     <tr>
#       <th id="T_b04cd_level0_row4" class="row_heading level0 row4" >20 to 24 years 2019 (Estimate)</th>
#       <td id="T_b04cd_row4_col0" class="data row4 col0" >3,220.00</td>
#       <td id="T_b04cd_row4_col1" class="data row4 col1" >6.49</td>
#       <td id="T_b04cd_row4_col2" class="data row4 col2" >2.57</td>
#       <td id="T_b04cd_row4_col3" class="data row4 col3" >0.00</td>
#       <td id="T_b04cd_row4_col4" class="data row4 col4" >5.30</td>
#       <td id="T_b04cd_row4_col5" class="data row4 col5" >6.10</td>
#       <td id="T_b04cd_row4_col6" class="data row4 col6" >7.00</td>
#       <td id="T_b04cd_row4_col7" class="data row4 col7" >31.80</td>
#     </tr>
#     <tr>
#       <th id="T_b04cd_level0_row5" class="row_heading level0 row5" >25 to 29 years 2019 (Estimate)</th>
#       <td id="T_b04cd_row5_col0" class="data row5 col0" >3,220.00</td>
#       <td id="T_b04cd_row5_col1" class="data row5 col1" >6.28</td>
#       <td id="T_b04cd_row5_col2" class="data row5 col2" >1.61</td>
#       <td id="T_b04cd_row5_col3" class="data row5 col3" >0.00</td>
#       <td id="T_b04cd_row5_col4" class="data row5 col4" >5.30</td>
#       <td id="T_b04cd_row5_col5" class="data row5 col5" >6.10</td>
#       <td id="T_b04cd_row5_col6" class="data row5 col6" >7.00</td>
#       <td id="T_b04cd_row5_col7" class="data row5 col7" >16.60</td>
#     </tr>
#     <tr

# %%
planning_methods.descriptive_stats_table(acs_df['2019 Percent Female'], 
      who = "Percent female population by age",
      what = "descriptive statistics",
      when = "in 2015-2019",
      where = "for all US counties")
# Out:
# <style type="text/css">
# #T_e4cda caption {
#   text-align: center;
#   caption-side: top;
#   font-size: 150%;
#   color: black;
# }
# #T_e4cda_row0_col0, #T_e4cda_row0_col1, #T_e4cda_row0_col2, #T_e4cda_row0_col3, #T_e4cda_row0_col4, #T_e4cda_row0_col5, #T_e4cda_row0_col6, #T_e4cda_row0_col7, #T_e4cda_row1_col0, #T_e4cda_row1_col1, #T_e4cda_row1_col2, #T_e4cda_row1_col3, #T_e4cda_row1_col4, #T_e4cda_row1_col5, #T_e4cda_row1_col6, #T_e4cda_row1_col7, #T_e4cda_row2_col0, #T_e4cda_row2_col1, #T_e4cda_row2_col2, #T_e4cda_row2_col3, #T_e4cda_row2_col4, #T_e4cda_row2_col5, #T_e4cda_row2_col6, #T_e4cda_row2_col7, #T_e4cda_row3_col0, #T_e4cda_row3_col1, #T_e4cda_row3_col2, #T_e4cda_row3_col3, #T_e4cda_row3_col4, #T_e4cda_row3_col5, #T_e4cda_row3_col6, #T_e4cda_row3_col7, #T_e4cda_row4_col0, #T_e4cda_row4_col1, #T_e4cda_row4_col2, #T_e4cda_row4_col3, #T_e4cda_row4_col4, #T_e4cda_row4_col5, #T_e4cda_row4_col6, #T_e4cda_row4_col7, #T_e4cda_row5_col0, #T_e4cda_row5_col1, #T_e4cda_row5_col2, #T_e4cda_row5_col3, #T_e4cda_row5_col4, #T_e4cda_row5_col5, #T_e4cda_row5_col6, #T_e4cda_row5_col7, #T_e4cda_row6_col0, #T_e4cda_row6_col1, #T_e4cda_row6_col2, #T_e4cda_row6_col3, #T_e4cda_row6_col4, #T_e4cda_row6_col5, #T_e4cda_row6_col6, #T_e4cda_row6_col7, #T_e4cda_row7_col0, #T_e4cda_row7_col1, #T_e4cda_row7_col2, #T_e4cda_row7_col3, #T_e4cda_row7_col4, #T_e4cda_row7_col5, #T_e4cda_row7_col6, #T_e4cda_row7_col7, #T_e4cda_row8_col0, #T_e4cda_row8_col1, #T_e4cda_row8_col2, #T_e4cda_row8_col3, #T_e4cda_row8_col4, #T_e4cda_row8_col5, #T_e4cda_row8_col6, #T_e4cda_row8_col7, #T_e4cda_row9_col0, #T_e4cda_row9_col1, #T_e4cda_row9_col2, #T_e4cda_row9_col3, #T_e4cda_row9_col4, #T_e4cda_row9_col5, #T_e4cda_row9_col6, #T_e4cda_row9_col7, #T_e4cda_row10_col0, #T_e4cda_row10_col1, #T_e4cda_row10_col2, #T_e4cda_row10_col3, #T_e4cda_row10_col4, #T_e4cda_row10_col5, #T_e4cda_row10_col6, #T_e4cda_row10_col7, #T_e4cda_row11_col0, #T_e4cda_row11_col1, #T_e4cda_row11_col2, #T_e4cda_row11_col3, #T_e4cda_row11_col4, #T_e4cda_row11_col5, #T_e4cda_row11_col6, #T_e4cda_row11_col7, #T_e4cda_row12_col0, #T_e4cda_row12_col1, #T_e4cda_row12_col2, #T_e4cda_row12_col3, #T_e4cda_row12_col4, #T_e4cda_row12_col5, #T_e4cda_row12_col6, #T_e4cda_row12_col7, #T_e4cda_row13_col0, #T_e4cda_row13_col1, #T_e4cda_row13_col2, #T_e4cda_row13_col3, #T_e4cda_row13_col4, #T_e4cda_row13_col5, #T_e4cda_row13_col6, #T_e4cda_row13_col7, #T_e4cda_row14_col0, #T_e4cda_row14_col1, #T_e4cda_row14_col2, #T_e4cda_row14_col3, #T_e4cda_row14_col4, #T_e4cda_row14_col5, #T_e4cda_row14_col6, #T_e4cda_row14_col7, #T_e4cda_row15_col0, #T_e4cda_row15_col1, #T_e4cda_row15_col2, #T_e4cda_row15_col3, #T_e4cda_row15_col4, #T_e4cda_row15_col5, #T_e4cda_row15_col6, #T_e4cda_row15_col7, #T_e4cda_row16_col0, #T_e4cda_row16_col1, #T_e4cda_row16_col2, #T_e4cda_row16_col3, #T_e4cda_row16_col4, #T_e4cda_row16_col5, #T_e4cda_row16_col6, #T_e4cda_row16_col7, #T_e4cda_row17_col0, #T_e4cda_row17_col1, #T_e4cda_row17_col2, #T_e4cda_row17_col3, #T_e4cda_row17_col4, #T_e4cda_row17_col5, #T_e4cda_row17_col6, #T_e4cda_row17_col7 {
#   text-align: right;
#   font-size: 20pt;
#   border: 2px solid black;
#   width: 100px;
# }
# </style>
# <table id="T_e4cda">
#   <caption>Table. Percent female population by age descriptive statistics for all US counties in 2015-2019.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4cda_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_e4cda_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_e4cda_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_e4cda_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_e4cda_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_e4cda_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_e4cda_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_e4cda_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4cda_level0_row0" class="row_heading level0 row0" >Under 5 years 2019 (Estimate)</th>
#       <td id="T_e4cda_row0_col0" class="data row0 col0" >3,220.00</td>
#       <td id="T_e4cda_row0_col1" class="data row0 col1" >5.65</td>
#       <td id="T_e4cda_row0_col2" class="data row0 col2" >1.49</td>
#       <td id="T_e4cda_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_e4cda_row0_col4" class="data row0 col4" >4.90</td>
#       <td id="T_e4cda_row0_col5" class="data row0 col5" >5.60</td>
#       <td id="T_e4cda_row0_col6" class="data row0 col6" >6.20</td>
#       <td id="T_e4cda_row0_col7" class="data row0 col7" >36.40</td>
#     </tr>
#     <tr>
#       <th id="T_e4cda_level0_row1" class="row_heading level0 row1" >5 to 9 years 2019 (Estimate)</th>
#       <td id="T_e4cda_row1_col0" class="data row1 col0" >3,220.00</td>
#       <td id="T_e4cda_row1_col1" class="data row1 col1" >5.96</td>
#       <td id="T_e4cda_row1_col2" class="data row1 col2" >1.41</td>
#       <td id="T_e4cda_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_e4cda_row1_col4" class="data row1 col4" >5.10</td>
#       <td id="T_e4cda_row1_col5" class="data row1 col5" >5.90</td>
#       <td id="T_e4cda_row1_col6" class="data row1 col6" >6.70</td>
#       <td id="T_e4cda_row1_col7" class="data row1 col7" >14.10</td>
#     </tr>
#     <tr>
#       <th id="T_e4cda_level0_row2" class="row_heading level0 row2" >10 to 14 years 2019 (Estimate)</th>
#       <td id="T_e4cda_row2_col0" class="data row2 col0" >3,220.00</td>
#       <td id="T_e4cda_row2_col1" class="data row2 col1" >6.26</td>
#       <td id="T_e4cda_row2_col2" class="data row2 col2" >1.41</td>
#       <td id="T_e4cda_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_e4cda_row2_col4" class="data row2 col4" >5.50</td>
#       <td id="T_e4cda_row2_col5" class="data row2 col5" >6.20</td>
#       <td id="T_e4cda_row2_col6" class="data row2 col6" >7.00</td>
#       <td id="T_e4cda_row2_col7" class="data row2 col7" >16.90</td>
#     </tr>
#     <tr>
#       <th id="T_e4cda_level0_row3" class="row_heading level0 row3" >15 to 19 years 2019 (Estimate)</th>
#       <td id="T_e4cda_row3_col0" class="data row3 col0" >3,220.00</td>
#       <td id="T_e4cda_row3_col1" class="data row3 col1" >6.18</td>
#       <td id="T_e4cda_row3_col2" class="data row3 col2" >1.63</td>
#       <td id="T_e4cda_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_e4cda_row3_col4" class="data row3 col4" >5.38</td>
#       <td id="T_e4cda_row3_col5" class="data row3 col5" >6.00</td>
#       <td id="T_e4cda_row3_col6" class="data row3 col6" >6.80</td>
#       <td id="T_e4cda_row3_col7" class="data row3 col7" >19.70</td>
#     </tr>
#     <tr>
#       <th id="T_e4cda_level0_row4" class="row_heading level0 row4" >20 to 24 years 2019 (Estimate)</th>
#       <td id="T_e4cda_row4_col0" class="data row4 col0" >3,220.00</td>
#       <td id="T_e4cda_row4_col1" class="data row4 col1" >5.80</td>
#       <td id="T_e4cda_row4_col2" class="data row4 col2" >2.31</td>
#       <td id="T_e4cda_row4_col3" class="data row4 col3" >0.00</td>
#       <td id="T_e4cda_row4_col4" class="data row4 col4" >4.80</td>
#       <td id="T_e4cda_row4_col5" class="data row4 col5" >5.40</td>
#       <td id="T_e4cda_row4_col6" class="data row4 col6" >6.30</td>
#       <td id="T_e4cda_row4_col7" class="data row4 col7" >28.00</td>
#     </tr>
#     <tr>
#       <th id="T_e4cda_level0_row5" class="row_heading level0 row5" >25 to 29 years 2019 (Estimate)</th>
#       <td id="T_e4cda_row5_col0" class="data row5 col0" >3,220.00</td>
#       <td id="T_e4cda_row5_col1" class="data row5 col1" >5.76</td>
#       <td id="T_e4cda_row5_col2" class="data row5 col2" >1.36</td>
#       <td id="T_e4cda_row5_col3" class="data row5 col3" >0.00</td>
#       <td id="T_e4cda_row5_col4" class="data row5 col4" >5.00</td>
#       <td id="T_e4cda_row5_col5" class="data row5 col5" >5.70</td>
#       <td id="T_e4cda_row5_col6" class="data row5 col6" >6.40</td>
#       <td id="T_e4cda_row5_col7" class="data row5 col7" >15.50</td>
#     </tr>
#     <

# %% [markdown]
# ## Step 4: Explore Data - Z-Score Outliers
# A way to identify outliers is by looking at the z-score, or the number of standard deviations an observation falls from the mean.
# The formula for z-score is
#
# >$z = \frac{observation - mean}{{standard deviation}}$
#
# If a z-score is greater than or less than 3 it would be considered an outlier.

# %%
outliers = planning_methods.find_zscore_outliers(acs_df[f'{year} Percent {sex}'],f'{agecohort} years {year}')
outliers.head()
# Out:
#            Geography         Geographic Area Name  \
# 3101  0500000US51750       Radford city, Virginia
# 198   0500000US51830  Williamsburg city, Virginia
# 769   0500000US46027    Clay County, South Dakota
# 693   0500000US16065        Madison County, Idaho
# 1433  0500000US20161         Riley County, Kansas
#
#       Total population 2019 (Estimate)  Total population 2019 (MOE)  \
# 3101                              9303                        137.0
# 198                               7998                        122.0
# 769                               7124                        102.0
# 693                              19219                        160.0
# 1433                             35308                        193.0
#
#       Under 5 years 2019 (Estimate)  Under 5 years 2019 (MOE)  \
# 3101                            2.7                       0.4
# 198                             2.0                       0.6
# 769                             4.4                       0.6
# 693                             9.2                       0.4
# 1433                            5.9                       0.2
#
#       5 to 9 years 2019 (Estimate)  5 to 9 years 2019 (MOE)  \
# 3101                           3.5                      1.2
# 198                            2.7                      0.8
# 769                            4.4                      1.2
# 693                            7.0                      1.0
# 1433                           4.6                      0.6
#
#       10 to 14 years 2019 (Estimate)  10 to 14 years 2019 (MOE)  ...  \
# 3101                             1.6                        1.1  ...
# 198                              1.5                        0.8  ...
# 769                              4.1                        1.2  ...
# 693                              5.9                        1.0  ...
# 1433                             4.3                        0.6  ...
#
#       80 to 84 years 2019 (Estimate)  80 to 84 years 2019 (MOE)  \
# 3101                             1.3                        0.6
# 198                              2.7                        0.7
# 769                              1.4                        0.6
# 693                              0.7                        0.3
# 1433                             0.7                        0.2
#
#       85 years and over 2019 (Estimate)  85 years and over 2019 (MOE)  state  \
# 3101                                1.7                           0.7     51
# 198                                 1.1                           0.6     51
# 769                                 2.7                           0.7     46
# 693                                 1.2                           0.4     16
# 1433                                2.2                           0.4     20
#
#       county  20 to 24 years 2019 Z-score  \
# 3101     750                     9.593563
# 198      830                     7.951414
# 769      027                     7.951414
# 693      065                     6.957483
# 1433     161                     6.914268
#
#       Z-score Outlier 20 to 24 years 2019 (Estimate)  \
# 3101                                               1
# 198                                                1
# 769                                                1
# 693                                                1
# 1433                                               1
#
#       20 to 24 years 2019 (Estimate) SE  20 to 24 years 2019 (Estimate) CV
# 3101                           1.033435                           0.036908
# 198                            1.641337                           0.067824
# 769                            1.276596                           0.052752
# 693                            0.547112                           0.024982
# 1433                           0.303951                           0.013943
#
# [5 rows x 46 columns]

# %%
planning_methods.descriptive_stats_table(outliers, 
      who = f"Percent {sex} population by age",
      what = "descriptive statistics",
      when = "in 2015-2019",
      where = "for outlier US counties")
# Out:
# <style type="text/css">
# #T_1075f caption {
#   text-align: center;
#   caption-side: top;
#   font-size: 150%;
#   color: black;
# }
# #T_1075f_row0_col0, #T_1075f_row0_col1, #T_1075f_row0_col2, #T_1075f_row0_col3, #T_1075f_row0_col4, #T_1075f_row0_col5, #T_1075f_row0_col6, #T_1075f_row0_col7, #T_1075f_row1_col0, #T_1075f_row1_col1, #T_1075f_row1_col2, #T_1075f_row1_col3, #T_1075f_row1_col4, #T_1075f_row1_col5, #T_1075f_row1_col6, #T_1075f_row1_col7, #T_1075f_row2_col0, #T_1075f_row2_col1, #T_1075f_row2_col2, #T_1075f_row2_col3, #T_1075f_row2_col4, #T_1075f_row2_col5, #T_1075f_row2_col6, #T_1075f_row2_col7, #T_1075f_row3_col0, #T_1075f_row3_col1, #T_1075f_row3_col2, #T_1075f_row3_col3, #T_1075f_row3_col4, #T_1075f_row3_col5, #T_1075f_row3_col6, #T_1075f_row3_col7, #T_1075f_row4_col0, #T_1075f_row4_col1, #T_1075f_row4_col2, #T_1075f_row4_col3, #T_1075f_row4_col4, #T_1075f_row4_col5, #T_1075f_row4_col6, #T_1075f_row4_col7, #T_1075f_row5_col0, #T_1075f_row5_col1, #T_1075f_row5_col2, #T_1075f_row5_col3, #T_1075f_row5_col4, #T_1075f_row5_col5, #T_1075f_row5_col6, #T_1075f_row5_col7, #T_1075f_row6_col0, #T_1075f_row6_col1, #T_1075f_row6_col2, #T_1075f_row6_col3, #T_1075f_row6_col4, #T_1075f_row6_col5, #T_1075f_row6_col6, #T_1075f_row6_col7, #T_1075f_row7_col0, #T_1075f_row7_col1, #T_1075f_row7_col2, #T_1075f_row7_col3, #T_1075f_row7_col4, #T_1075f_row7_col5, #T_1075f_row7_col6, #T_1075f_row7_col7, #T_1075f_row8_col0, #T_1075f_row8_col1, #T_1075f_row8_col2, #T_1075f_row8_col3, #T_1075f_row8_col4, #T_1075f_row8_col5, #T_1075f_row8_col6, #T_1075f_row8_col7, #T_1075f_row9_col0, #T_1075f_row9_col1, #T_1075f_row9_col2, #T_1075f_row9_col3, #T_1075f_row9_col4, #T_1075f_row9_col5, #T_1075f_row9_col6, #T_1075f_row9_col7, #T_1075f_row10_col0, #T_1075f_row10_col1, #T_1075f_row10_col2, #T_1075f_row10_col3, #T_1075f_row10_col4, #T_1075f_row10_col5, #T_1075f_row10_col6, #T_1075f_row10_col7, #T_1075f_row11_col0, #T_1075f_row11_col1, #T_1075f_row11_col2, #T_1075f_row11_col3, #T_1075f_row11_col4, #T_1075f_row11_col5, #T_1075f_row11_col6, #T_1075f_row11_col7, #T_1075f_row12_col0, #T_1075f_row12_col1, #T_1075f_row12_col2, #T_1075f_row12_col3, #T_1075f_row12_col4, #T_1075f_row12_col5, #T_1075f_row12_col6, #T_1075f_row12_col7, #T_1075f_row13_col0, #T_1075f_row13_col1, #T_1075f_row13_col2, #T_1075f_row13_col3, #T_1075f_row13_col4, #T_1075f_row13_col5, #T_1075f_row13_col6, #T_1075f_row13_col7, #T_1075f_row14_col0, #T_1075f_row14_col1, #T_1075f_row14_col2, #T_1075f_row14_col3, #T_1075f_row14_col4, #T_1075f_row14_col5, #T_1075f_row14_col6, #T_1075f_row14_col7, #T_1075f_row15_col0, #T_1075f_row15_col1, #T_1075f_row15_col2, #T_1075f_row15_col3, #T_1075f_row15_col4, #T_1075f_row15_col5, #T_1075f_row15_col6, #T_1075f_row15_col7, #T_1075f_row16_col0, #T_1075f_row16_col1, #T_1075f_row16_col2, #T_1075f_row16_col3, #T_1075f_row16_col4, #T_1075f_row16_col5, #T_1075f_row16_col6, #T_1075f_row16_col7, #T_1075f_row17_col0, #T_1075f_row17_col1, #T_1075f_row17_col2, #T_1075f_row17_col3, #T_1075f_row17_col4, #T_1075f_row17_col5, #T_1075f_row17_col6, #T_1075f_row17_col7 {
#   text-align: right;
#   font-size: 20pt;
#   border: 2px solid black;
#   width: 100px;
# }
# </style>
# <table id="T_1075f">
#   <caption>Table. Percent Female population by age descriptive statistics for outlier US counties in 2015-2019.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1075f_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_1075f_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_1075f_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_1075f_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_1075f_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_1075f_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_1075f_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_1075f_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1075f_level0_row0" class="row_heading level0 row0" >Under 5 years 2019 (Estimate)</th>
#       <td id="T_1075f_row0_col0" class="data row0 col0" >77.00</td>
#       <td id="T_1075f_row0_col1" class="data row0 col1" >5.03</td>
#       <td id="T_1075f_row0_col2" class="data row0 col2" >1.27</td>
#       <td id="T_1075f_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_
row5_col3" class="data row5 col3" >0.00</td>
#       <td id="T_1075f_row5_col4" class="data row5 col4" >5.80</td>
#       <td id="T_1075f_row5_col5" class="data row5 col5" >7.00</td>
#       <td id="T_1075f_row5_col6" class="data row5 col6" >7.60</td>
#       <td id="T_1075f_row5_col7" class="data row5 col7" >10.90</td>
#     </tr>
#     <tr>

# %%
outliers.loc[(outliers['state'] == state) & (outliers['20 to 24 years 2019 (Estimate) CV'] < 0.1)]
# Out:
#            Geography   Geographic Area Name  Total population 2019 (Estimate)  \
# 488   0500000US48041   Brazos County, Texas                            110352
# 2897  0500000US48471   Walker County, Texas                             30104
# 2791  0500000US48273  Kleberg County, Texas                             15318
# 508   0500000US48143    Erath County, Texas                             21494
# 482   0500000US48473   Waller County, Texas                             25988
#
#       Total population 2019 (MOE)  Under 5 years 2019 (Estimate)  \
# 488                          76.0                            6.1
# 2897                        238.0                            4.8
# 2791                        235.0                            6.8
# 508                         278.0                            5.4
# 482                         157.0                            5.7
#
#       Under 5 years 2019 (MOE)  5 to 9 years 2019 (Estimate)  \
# 488                        0.1                           5.8
# 2897                       0.1                           4.2
# 2791                       0.6                           7.2
# 508                        0.3                           5.8
# 482                        0.4                           6.5
#
#       5 to 9 years 2019 (MOE)  10 to 14 years 2019 (Estimate)  \
# 488                       0.4                             5.3
# 2897                      0.7                             6.0
# 2791                      1.2                             6.1
# 508                       1.5                             5.1
# 482                       1.0                             7.4
#
#       10 to 14 years 2019 (MOE)  ...  80 to 84 years 2019 (Estimate)  \
# 488                         0.4  ...                             1.2
# 2897                        0.8  ...                             1.8
# 2791                        1.4  ...                             1.5
# 508                         1.4  ...                             1.7
# 482                         1.1  ...                             1.3
#
#       80 to 84 years 2019 (MOE)  85 years and over 2019 (Estimate)  \
# 488                         0.2                                1.2
# 2897                        0.6                                3.0
# 2791                        0.7                                2.3
# 508                         0.6                                2.6
# 482                         0.5                                1.6
#
#       85 years and over 2019 (MOE)  state  county  \
# 488                            0.2     48     041
# 2897                           0.6     48     471
# 2791                           0.8     48     273
# 508                            0.7     48     143
# 482                            0.5     48     473
#
#       20 to 24 years 2019 Z-score  \
# 488                      5.315334
# 2897                     5.099262
# 2791                     4.451046
# 508                      4.321403
# 482                      3.543543
#
#       Z-score Outlier 20 to 24 years 2019 (Estimate)  \
# 488                                                1
# 2897                                               1
# 2791                                               1
# 508                                                1
# 482                                                1
#
#       20 to 24 years 2019 (Estimate) SE  20 to 24 years 2019 (Estimate) CV
# 488                            0.121581                           0.006717
# 2897                           1.155015                           0.065626
# 2791                           0.729483                           0.045310
# 508                            0.972644                           0.061560
# 482                            0.911854                           0.065132
#
# [5 rows x 46 columns]

# %% [markdown]
# ## Generate Links to Sources
# Public sources of Census data include Census Reporter, ACS Narratitve Profiles, and data.census.gov. The sources can be quickly located using links based on Geography Codes.

# %%
planning_methods.generate_source_county_links(year,'48041')
# Out:
# For an ACS Narrative Profile click on link:
# https://www.census.gov/acs/www/data/data-tables-and-tools/narrative-profiles/2019/report.php?geotype=county&state=48&county=041
#
#
# For a Census Reporter Profile click on link:
# https://censusreporter.org/profiles/05000US48041
#
#
# For data.census.gov data click on link:
# https://data.census.gov/cedsci/table?tid=ACSST5Y2019.S0101&g=0500000US48041
